# %% [markdown]
# <a href="https://colab.research.google.com/github/Mwadz/Data-Cleaning-and-EDA/blob/main/Metropolitan_Area_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv("/content/Metropolitan_Areas_Data-data.csv")

# %%
data.head()
# Out:
#    land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0       1384          78.1            12.3       25627          69678
# 1       3719          43.9             9.4       13326          43292
# 2       3553          37.4            10.7        9724          33731
# 3       3916          29.9             8.8        6402          24167
# 4       2480          31.5            10.5        8502          16751
#
#    graduates  work_force  income  region  crime_rate
# 0       50.1      4083.9   72100       1       75.55
# 1       53.9      3305.9   54542       2       56.03
# 2       50.6      2066.3   33216       1       41.32
# 3       52.2      1966.7   32906       2       67.38
# 4       66.1      1514.5   26573       4       80.19

# %%
data.columns
# Out:
# Index(['land_area', 'percent_city', 'percent_senior', 'physicians',
#        'hospital_beds', 'graduates', 'work_force', 'income', 'region',
#        'crime_rate'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   land_area       99 non-null     int64
#  1   percent_city    99 non-null     float64
#  2   percent_senior  99 non-null     float64
#  3   physicians      99 non-null     int64
#  4   hospital_beds   99 non-null     int64
#  5   graduates       99 non-null     float64
#  6   work_force      99 non-null     float64
#  7   income          99 non-null     int64
#  8   region          99 non-null     int64
#  9   crime_rate      99 non-null     float64
# dtypes: float64(5), int64(5)
# memory usage: 7.9 KB

# %% [markdown]
# ## Q3.
# Day 6: Assignment 1
# This exercise uses the SMA Dataset, available here: https://raw.githubusercontent.com/dphi-official/Datasets/master/Standard_Metropolitan_Areas_Data-data.csv
#
# Which of the following is the correct correlation matrix among the features of the dataset?
#
# Select one:

# %%
data.corr()
# Out:
#                 land_area  percent_city  percent_senior  physicians  \
# land_area        1.000000     -0.077320        0.092226    0.085054
# percent_city    -0.077320      1.000000       -0.250995    0.067391
# percent_senior   0.092226     -0.250995        1.000000    0.056454
# physicians       0.085054      0.067391        0.056454    1.000000
# hospital_beds    0.081034      0.052898        0.083775    0.974241
# graduates        0.088728      0.076720       -0.155695    0.049500
# work_force       0.135792      0.016011        0.035240    0.965597
# income           0.111404      0.019235        0.046073    0.976209
# region           0.292392      0.235880       -0.242811   -0.140961
# crime_rate       0.293907      0.159596       -0.177992    0.187763
#
#                 hospital_beds  graduates  work_force    income    region  \
# land_area            0.081034   0.088728    0.135792  0.111404  0.292392
# ...

# %% [markdown]
# # Q4.
# Day 6: Assignment 1
# This exercise uses the SMA Dataset, available here: https://raw.githubusercontent.com/dphi-official/Datasets/master/Standard_Metropolitan_Areas_Data-data.csv
#
# Which of the following is the first five land area of the metropolitan area data which are located in region 4?
#
# Select one:

# %%
# Using the query method to group the data by product and extract the land areas in region 4
region4 = data.query("region == 4")['land_area']

region4.head()
# Out:
# 4      2480
# 13      782
# 14     4226
# 18    27293
# 20     9155
# Name: land_area, dtype: int64

# %% [markdown]
# # Q5.
# Day 6: Assignment 1
# This exercise uses the SMA Dataset, available here: https://raw.githubusercontent.com/dphi-official/Datasets/master/Standard_Metropolitan_Areas_Data-data.csv
#
# Which of the following is the correct line plot between land area and crime rate?
#
# Select one:

# %%
import seaborn as sns
sns.lineplot( x = "land_area",
             y = "crime_rate",
             data = data);

# %% [markdown]
# # Q6.
# Day 6: Assignment 1
# This exercise uses the SMA Dataset, available here: https://raw.githubusercontent.com/dphi-official/Datasets/master/Standard_Metropolitan_Areas_Data-data.csv
#
# Which of the following correlation information is correct between two variables.
#
# Select one:

# %%
sns.scatterplot(x='physicians', y='hospital_beds', data=data, hue='region',
                    sizes=(30, 200), legend='brief')
# Out:
# <Axes: xlabel='physicians', ylabel='hospital_beds'>

# %% [markdown]
# # Q7.
# Day 6: Assignment 1
# This exercise uses the SMA Dataset, available here: https://raw.githubusercontent.com/dphi-official/Datasets/master/Standard_Metropolitan_Areas_Data-data.csv
#
# Which of the following is the correct bar plot of geographic regions?
#
# Select one:

# %%
sns.countplot(x='region', data=data)
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %% [markdown]
# # Q8.
# Day 6: Assignment 1
# This exercise uses the SMA Dataset, available here: https://raw.githubusercontent.com/dphi-official/Datasets/master/Standard_Metropolitan_Areas_Data-data.csv
#
# Which of the following is showing the correct distribution of income of the Metropolitan areas?
#
# Select one:

# %%
sns.histplot(data = data, x = "income", kde = True)
# Out:
# <Axes: xlabel='income', ylabel='Count'>
